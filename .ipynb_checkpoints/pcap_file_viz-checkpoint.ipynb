# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import pyshark
import os
import math

# %%
fname = 'los_4_ap_in_lab'
df = pd.read_csv(fname + ".csv")
df.head(20)
# Out:
#     Unnamed: 0  phy  data_rate  channel  frequency  signal_dbm  noise_dbm  \
# 0            0    5         12      149       5745         -78        -96
# 1            1    5         12      149       5745         -47        -96
# 2            2    5         12      149       5745         -66        -96
# 3            3    5          6      149       5745         -90        -96
# 4            4    5         12      149       5745         -50        -96
# 5            5    5         12      149       5745         -74        -96
# 6            6    5         12      149       5745         -80        -96
# 7            7    5         12      149       5745         -83        -96
# 8            8    5         12      149       5745         -80        -96
# 9            9    5         12      149       5745         -86        -96
# 10          10    5         12      149       5745         -77        -96
# 11          11    5         12      149       5745         -79        -96
# 12          12    5         24      149       5745         -80        -96
# 13          13    5         24      149       5745         -80        -96
# 14          14    5         12      149       5745         -84        -96
# 15          15    5         12      149       5745         -83        -96
# 16          16    5         12      149       5745         -80        -96
# 17          17    5         12      149       5745         -86        -96
# 18          18    5         12      149       5745         -47        -96
# 19          19    5         12      149       5745         -80        -96
#
#     snr            tx_addr  timestamp  duration      ifs  start_tsf    end_tsf
# 0    18  f6:0a:5c:59:72:df  202799000       252      NaN  202798748  202799000
# 1    49  5e:29:73:5b:30:00  202804018       272   4746.0  202803746  202804018
# 2    30  3e:d1:9b:c7:a4:de  202819411       272  15121.0  202819139  202819411
# 3     6  54:e4:3a:ec:fb:65  202837999       360  18228.0  202837639  202837999
# 4    46  f2:da:61:dd:98:c5  202851181       268  12914.0  202850913  202851181
# 5    22  22:ec:75:a8:8a:31  202853078       244   1653.0  202852834  202853078
# 6    16  fa:44:8d:e1:c7:1b  202862595       244   9273.0  202862351  202862595
# 7    13  72:d1:72:1d:22:a1  202862911       256     60.0  202862655  202862911
# 8    16  56:68:e2:c2:8d:d5  202863921       280    730.0  202863641  202863921
# 9    10  d2:00:04:7e:2c:ab  202878129       244  13964.0  202877885  202878129
# 10   19  c2:21:7d:48:b5:63  202894359       240  15990.0  202894119  202894359
# 11   17  f6:0a:5c:59:72:df  202897922       252   3311.0  202897670  202897922
# 12   16                NaN  202913404        28  15454.0  202913376  202913404
# 13   16                NaN  202913809        28    377.0  202913781  202913809
# 14   12  72:d1:72:1d:22:a1  202916548       256   2483.0  202916292  202916548
# 15   13  72:d1:72:1d:22:a1  202922965       452   5965.0  202922513  202922965
# 16   16  56:68:e2:c2:8d:d5  202923496       476     55.0  202923020  202923496
# 17   10  d2:00:04:7e:2c:ab  202926699       440   2763.0  202926259  202926699
# 18   49  5e:29:73:5b:30:00  202927253       540     14.0  202926713  202927253
# 19   16  fa:44:8d:e1:c7:1b  202932104       244   4607.0  202931860  202932104

# %%
# ACCESS_POINT_MAC_ADDR = '00:1f:26:41:f0:00'
ACCESS_POINT_MAC_ADDR = '3e:d1:9b:c7:a4:de'

# %%
unique_tx = df['tx_addr'].unique()
# print(unique_tx)
print("number of unique MAC addresses in packet capture: ", len(unique_tx))
print("MAC addresses in packet capture per value count:")
display(df.value_counts("tx_addr"))

# filter by MAC address
pkts_from_ap_df = df[df['tx_addr'] == ACCESS_POINT_MAC_ADDR]
print(pkts_from_ap_df.shape)

# filtering: implement Savitzky-Golay method to preserve spikes and not excessively smooth vizualized patterns 




pkts_from_ap_df.to_csv(fname + '_filtered_by_mac_addr.csv')
# Out:
# number of unique MAC addresses in packet capture:  84
# MAC addresses in packet capture per value count:
# tx_addr
# 3e:d1:9b:c7:a4:de    1583
# 5e:29:73:5b:30:00    1563
# 22:ec:75:a8:8a:31    1547
# f2:da:61:dd:98:c5    1492
# 56:68:e2:c2:8d:d5    1358
#                      ...
# 34:f6:4b:95:fe:d4       1
# 1a:a8:50:6a:aa:97       1
# 78:ba:f9:ec:b1:f0       1
# 52:6b:a9:19:82:49       1
# 40:e3:d6:da:c4:10       1
# Name: count, Length: 83, dtype: int64
# (1583, 14)
#        Unnamed: 0  phy  data_rate  channel  frequency  signal_dbm  noise_dbm  \
# 2               2    5         12      149       5745         -66        -96
# 25             25    5         12      149       5745         -66        -96
# 28             28    5         12      149       5745         -65        -96
# 50             50    5         12      149       5745         -65        -96
# 55             55    5         12      149       5745         -65        -96
# ...           ...  ...        ...      ...        ...         ...        ...
# 30522       30522    5         12      149       5745         -63        -97
# 30543       30543    5         12      149       5745         -60        -97
# 30550       30550    5         12      149       5745         -60        -97
# 30562       30562    5         12      149       5745         -60        -97
# 30576       30576    5         12      149       5745         -62        -97
#
#        snr            tx_addr  timestamp  duration      ifs  start_tsf  \
# 2       30  3e:d1:9b:c7:a4:de  202819411       272  15121.0  202819139
# 25      30  3e:d1:9b:c7:a4:de  202940814       544   -129.0  202940270
# 28      31  3e:d1:9b:c7:a4:de  202949305       272   1707.0  202949033
# 50      31  3e:d1:9b:c7:a4:de  203064030       272   1977.0  203063758
# 55      31  3e:d1:9b:c7:a4:de  203072073       544    936.0  203071529
# ...    ...                ...        ...       ...      ...        ...
# 30522   34  3e:d1:9b:c7:a4:de  323558865       272  22531.0  323558593
# 30543   37  3e:d1:9b:c7:a4:de  323650587       544   1808.0  323650043
# 30550   37  3e:d1:9b:c7:a4:de  323672408       272  10364.0  323672136
# 30562   37  3e:d1:9b:c7:a4:de  323768380       272  18371.0  323768108
# 30576   35  3e:d1:9b:c7:a4:de  323884478       272   5847.0  323884206
#
#          end_tsf
# 2      202819411
# 25     202940814
# 28     202949305
# 50     203064030
# 55     203072073
# ...          ...
# 30522  323558865
# 30543  323650587
# 30550  323672408
# 30562  323768380
# 30576  323884478
#
# [1583 rows x 14 columns]

# %%
d_col = 'distance'
f_col = 'frequency'
fspl = ((4*math.pi*df[d_col]*df[f_col]) / c)**2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3801         try:
# -> 3802             return self._engine.get_loc(casted_key)
#    3803         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-684e5349d98e> in <module>
#       1 d_col = 'distance'
#       2 f_col = 'frequency'
# ----> 3 fspl = ((4*math.pi*df[d_col]*df[f_col]) / c)**2
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    4088             if self.columns.nlevels > 1:
#    4089                 return self._getitem_multilevel(key)
# -> 4090             indexer = self.columns.get_loc(key)
#    4091             if is_integer(indexer):
#    4092                 indexer = [indexer]
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3807             ):
#    3808                 raise InvalidIndexError(key)
# -> 3809             raise KeyError(key) from err
#    3810         except TypeError:
#    3811             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'distance'

# %%
# df = file[["data_rate", "signal_dbm"]]
# df.plot(secondary_y = ['data_rate'])


trace1 = go.Scatter(x=df['timestamp'],
                    y=df['data_rate'],
                    name='data_rate_plot',
                    mode='lines',
                    yaxis='y1')
trace2 = go.Scatter(x=df['timestamp'],
                    y=df['signal_dbm'],
                    name='signal_dbm_plot',
                    mode='lines',
                    yaxis='y1')
# trace3 = go.Bar(x=df['Timestamp'],
#                 y=df['ModelDiff'],
#                 name='Diff',
#                 yaxis='y2'
#                 )
data = [trace1, trace2]
layout = go.Layout(title='CLE vs Model',
                   yaxis=dict(title='a'),
                   yaxis2=dict(title='b',
                               overlaying='y',
                               side='right'))
fig = go.Figure(data=data, layout=layout)
fig.write_html("testdump.html")
